# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pandas as pd
import numpy as np

# %%
def engineer_features(df):
    df = df.copy()
    df['pitch_velocity'] = df['pitch'].diff() / df['tick'].diff()
    df['yaw_velocity'] = df['yaw'].diff() / df['tick'].diff()

    df['pitch_acceleration'] = df['pitch_velocity'].diff() / df['tick'].diff()
    df['yaw_acceleration'] = df['yaw_velocity'].diff() / df['tick'].diff()

    df['pitch_jerk'] = df['pitch_acceleration'].diff() / df['tick'].diff()
    df['yaw_jerk'] = df['yaw_acceleration'].diff() / df['tick'].diff()

    df['cumulative_pitch'] = df['pitch'].cumsum()
    df['cumulative_yaw'] = df['yaw'].cumsum()

    for col in ['pitch', 'yaw']:
        df[f'{col}_mean'] = df[col].mean()
        df[f'{col}_std'] = df[col].std()
        df[f'{col}_min'] = df[col].min()
        df[f'{col}_max'] = df[col].max()
        df[f'{col}_range'] = df[f'{col}_max'] - df[f'{col}_min']

    return df.dropna()

# %%
def process_all_segments(input_dir, output_dir, category_name):
    os.makedirs(output_dir, exist_ok=True)
    for user_folder in os.listdir(input_dir):
        user_path = os.path.join(input_dir, user_folder)
        if not os.path.isdir(user_path):
            continue
        for file_name in os.listdir(user_path):
            if not file_name.endswith('.csv'):
                continue

            file_path = os.path.join(user_path, file_name)
            try:
                df = pd.read_csv(file_path)

                # Drop unused columns if present
                df = df.drop(columns=[col for col in ['name'] if col in df.columns])

                processed = engineer_features(df)
                save_path = os.path.join(output_dir, f"engineered_{file_name}")
                processed.to_csv(save_path, index=False)
                print(f"Processed: {save_path}")
            except Exception as e:
                print(f"Error processing {file_path}: {str(e)}")

# %%
base_input = "/content/drive/MyDrive/Skripsi/data/interim/parsed_csv"
base_output = "/content/drive/MyDrive/Skripsi/data/processed/features"

cheater_input = os.path.join(base_input, "cheater")
legit_input = os.path.join(base_input, "legit")
cheater_output = os.path.join(base_output, "cheater")
legit_output = os.path.join(base_output, "legit")

# %%
# Process both categories
process_all_segments(cheater_input, cheater_output, "cheater")
process_all_segments(legit_input, legit_output, "legit")
# Out:
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_5420_to_5720.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_2717_to_3017.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_2537_to_2837.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_2232_to_2532.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_5216_to_5516.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_5827_to_6127.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_1934_to_2234.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_2056_to_2356.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_4937_to_5237.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_5625_to_5925.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_2393_to_2693.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_6233_to_6533.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_6030_to_6330.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_6552_to_6852.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_1267_to_1567.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_6770_to_7070.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_707_to_1007.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_873_to_1173.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_513_to_813.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_3154_to_3454.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_3277_to_3577.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_1442_to_1742.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_311_to_611.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_4531_to_4831.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_1604_to_1904.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_3447_to_3747.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_1808_to_2108.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_4734_to_5034.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_3892_to_4192.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_4328_to_4628.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_7197_to_7497.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_2921_to_3221.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_7414_to_7714.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_3772_to_4072.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_3621_to_3921.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_1075_to_1375.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/cheater/engineered_thesis_test_cheat_kill_6993_to_7293.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_31433_to_31733.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_32036_to_32336.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_55282_to_55582.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_19243_to_19543.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_18998_to_19298.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_11928_to_12228.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_30932_to_31232.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_39940_to_40240.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_5008_to_5308.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_19477_to_19777.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_13254_to_13554.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_35960_to_36260.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_9322_to_9622.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_7398_to_7698.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_27305_to_27605.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_60763_to_61063.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_8170_to_8470.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_32387_to_32687.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_25963_to_26263.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_36818_to_37118.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_4726_to_5026.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_44934_to_45234.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_12636_to_12936.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_28445_to_28745.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_41034_to_41334.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_49569_to_49869.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_11583_to_11883.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_12375_to_12675.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_23273_to_23573.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_54152_to_54452.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_50471_to_50771.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_56241_to_56541.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_54475_to_54775.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_36159_to_36459.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_17725_to_18025.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_60135_to_60435.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_28147_to_28447.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_41215_to_41515.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_53965_to_54265.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_22461_to_22761.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_4671_to_4971.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_15442_to_15742.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_13067_to_13367.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_2500_to_2800.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_40026_to_40326.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_13108_to_13408.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_59306_to_59606.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_23042_to_23342.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_32311_to_32611.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_45378_to_45678.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_46391_to_46691.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_16216_to_16516.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_56377_to_56677.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_36613_to_36913.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_2314_to_2614.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_2143_to_2443.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_50596_to_50896.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_11761_to_12061.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_26437_to_26737.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_62868_to_63168.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_32123_to_32423.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_22357_to_22657.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_8143_to_8443.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_7552_to_7852.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_16287_to_16587.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_2011_to_2311.csv
# Processed: /content/drive/MyDrive/Skripsi/data/processed/features/legit/engineered_Copy of cheater(xxx)_kill_53773_to_54073.csv
